# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city = cities[302]
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()


city_weather
# Out:
# {'coord': {'lon': 90.2201, 'lat': 25.5198},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 72.46,
#   'feels_like': 73.98,
#   'temp_min': 72.46,
#   'temp_max': 72.46,
#   'pressure': 1009,
#   'humidity': 97,
#   'sea_level': 1009,
#   'grnd_level': 966},
#  'visibility': 10000,
#  'wind': {'speed': 2.89, 'deg': 87, 'gust': 3.22},
#  'clouds': {'all': 100},
#  'dt': 1664833529,
#  'sys': {'country': 'IN', 'sunrise': 1664841136, 'sunset': 1664883808},
#  'timezone': 19800,
#  'id': 1254046,
#  'name': 'Tura',
#  'cod': 200}

# %%
city_weather['weather'][0]['description']
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    time.sleep(2)
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        print(f"{i} sleeping...")
        time.sleep(90)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mehamn
# Processing Record 2 of Set 1 | borba
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | gizo
# Processing Record 5 of Set 1 | san cristobal
# Processing Record 6 of Set 1 | wajima
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | erzin
# Processing Record 9 of Set 1 | bay-khaak
# Processing Record 10 of Set 1 | ambilobe
# Processing Record 11 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | trzebnica
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | nacala
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | hirara
# Processing Record 25 of Set 1 | coahuayana
# Processing Record 26 of Set 1 | gimli
# Processing Record 27 of Set 1 | upington
# Processing Record 28 of Set 1 | mitsamiouli
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | praia da vitoria
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | marsa matruh
# Processing Record 33 of Set 1 | gamba
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | bitung
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | vanimo
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | rayachoti
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | sakakah
# Processing Record 45 of Set 1 | tazovskiy
# Processing Record 46 of Set 1 | husavik
# Processing Record 47 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | linxia
# Processing Record 50 of Set 1 | wattens
# 50 sleeping...
# Processing Record 1 of Set 2 | banamba
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | craigieburn
# Processing Record 6 of Set 2 | sierra vista
# Processing Record 7 of Set 2 | abeokuta
# Processing Record 8 of Set 2 | andapa
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | ust-nera
# Processing Record 11 of Set 2 | conde
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | cao bang
# Processing Record 16 of Set 2 | belaya gora
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | san rafael
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | ponta delgada
# Processing Record 24 of Set 2 | adrar
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | hamilton
# Processing Record 28 of Set 2 | astaneh-ye ashrafiyeh
# Processing Record 29 of Set 2 | port macquarie
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | mwene-ditu
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | elat
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | hofn
# Processing Record 43 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | kapustin yar-1
# City not found. Skipping...
# Processing Record 47 of Set 2 | svetlogorsk
# Processing Record 48 of Set 2 | te anau
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | donskoye
# 100 sleeping...
# Processing Record 1 of Set 3 | cajamarca
# Processing Record 2 of Set 3 | araouane
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | vyartsilya
# Processing Record 5 of Set 3 | touros
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | jiuquan
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | kuhestan
# City not found. Skipping...
# Processing Record 11 of Set 3 | tabou
# Processing Record 12 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 3 | verkhnevilyuysk
# Processing Record 14 of Set 3 | tinskoy
# Processing Record 15 of Set 3 | roebourne
# Processing Record 16 of Set 3 | kiunga
# Processing Record 17 of Set 3 | port blair
# Processing Record 18 of Set 3 | santa rosa
# Processing Record 19 of Set 3 | lashio
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | taoudenni
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | lata
# Processing Record 25 of Set 3 | goiatuba
# Processing Record 26 of Set 3 | sur
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | kirakira
# Processing Record 30 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 3 | daru
# Processing Record 32 of Set 3 | samarai
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | oktyabrskiy
# Processing Record 35 of Set 3 | shubarkuduk
# Processing Record 36 of Set 3 | progreso
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | qasigiannguit
# Processing Record 39 of Set 3 | hay river
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 3 | sidney
# Processing Record 43 of Set 3 | omsukchan
# Processing Record 44 of Set 3 | salihorsk
# Processing Record 45 of Set 3 | hovd
# Processing Record 46 of Set 3 | evensk
# Processing Record 47 of Set 3 | santa luzia
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | tabas
# Processing Record 50 of Set 3 | tautira
# 150 sleeping...
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | baykit
# Processing Record 3 of Set 4 | awjilah
# Processing Record 4 of Set 4 | sangar
# Processing Record 5 of Set 4 | buzmeyin
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | khani
# Processing Record 8 of Set 4 | sabang
# Processing Record 9 of Set 4 | neede
# Processing Record 10 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 4 | wencheng
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | ascension
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | san carlos de bariloche
# Processing Record 16 of Set 4 | saint-joseph
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | ridgecrest
# Processing Record 20 of Set 4 | high level
# Processing Record 21 of Set 4 | meulaboh
# Processing Record 22 of Set 4 | bouza
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | cayenne
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | anadyr
# Processing Record 27 of Set 4 | kyshtovka
# Processing Record 28 of Set 4 | sunderland
# Processing Record 29 of Set 4 | capoterra
# Processing Record 30 of Set 4 | paungde
# Processing Record 31 of Set 4 | naze
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | mountain home
# Processing Record 34 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 4 | sungaipenuh
# Processing Record 36 of Set 4 | san andres
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | stara synyava
# Processing Record 39 of Set 4 | mahina
# Processing Record 40 of Set 4 | harper
# Processing Record 41 of Set 4 | huarmey
# Processing Record 42 of Set 4 | hobe sound
# Processing Record 43 of Set 4 | mackay
# Processing Record 44 of Set 4 | liliw
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | gat
# Processing Record 49 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kruisfontein
# 200 sleeping...
# Processing Record 1 of Set 5 | mosquera
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | waddan
# Processing Record 4 of Set 5 | arlit
# Processing Record 5 of Set 5 | darhan
# Processing Record 6 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 5 | surat thani
# Processing Record 8 of Set 5 | butaritari
# Processing Record 9 of Set 5 | flin flon
# Processing Record 10 of Set 5 | gorontalo
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | kholmogory
# Processing Record 13 of Set 5 | kaeo
# Processing Record 14 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 5 | upernavik
# Processing Record 16 of Set 5 | souillac
# Processing Record 17 of Set 5 | sambava
# Processing Record 18 of Set 5 | saint-philippe
# Processing Record 19 of Set 5 | poole
# Processing Record 20 of Set 5 | toyooka
# Processing Record 21 of Set 5 | saint-augustin
# Processing Record 22 of Set 5 | la ronge
# Processing Record 23 of Set 5 | osa
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | sassandra
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | shetpe
# Processing Record 30 of Set 5 | tiznit
# Processing Record 31 of Set 5 | biak
# Processing Record 32 of Set 5 | eydhafushi
# Processing Record 33 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 34 of Set 5 | pechora
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | alta floresta
# Processing Record 38 of Set 5 | ubinskoye
# Processing Record 39 of Set 5 | vila velha
# Processing Record 40 of Set 5 | vila franca do campo
# Processing Record 41 of Set 5 | hashtrud
# Processing Record 42 of Set 5 | kushiro
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | suba
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | kampong cham
# Processing Record 47 of Set 5 | beringovskiy
# Processing Record 48 of Set 5 | hobyo
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | raglan
# 250 sleeping...
# Processing Record 1 of Set 6 | kirando
# Processing Record 2 of Set 6 | gravelbourg
# Processing Record 3 of Set 6 | basco
# Processing Record 4 of Set 6 | zalantun
# Processing Record 5 of Set 6 | chicama
# Processing Record 6 of Set 6 | bahia honda
# Processing Record 7 of Set 6 | havoysund
# Processing Record 8 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 6 | necochea
# Processing Record 10 of Set 6 | kuching
# Processing Record 11 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | kondinskoye
# Processing Record 13 of Set 6 | panambi
# Processing Record 14 of Set 6 | buraydah
# Processing Record 15 of Set 6 | yanam
# Processing Record 16 of Set 6 | pizarro
# Processing Record 17 of Set 6 | krasnoarmeysk
# Processing Record 18 of Set 6 | tuatapere
# Processing Record 19 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | tabuk
# Processing Record 22 of Set 6 | oranjestad
# Processing Record 23 of Set 6 | bambous virieux
# Processing Record 24 of Set 6 | maragogi
# Processing Record 25 of Set 6 | mulege
# Processing Record 26 of Set 6 | stonewall
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | saint anthony
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | chokwe
# Processing Record 31 of Set 6 | batemans bay
# Processing Record 32 of Set 6 | charcas
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | huanren
# Processing Record 37 of Set 6 | kavieng
# Processing Record 38 of Set 6 | aberdeen
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | blagoyevo
# Processing Record 41 of Set 6 | namatanai
# Processing Record 42 of Set 6 | mbandaka
# Processing Record 43 of Set 6 | sandy point
# Processing Record 44 of Set 6 | north bend
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | cairns
# Processing Record 47 of Set 6 | moranbah
# Processing Record 48 of Set 6 | chifeng
# Processing Record 49 of Set 6 | pervomayskoye
# Processing Record 50 of Set 6 | krasnousolskiy
# City not found. Skipping...
# 300 sleeping...
# Processing Record 1 of Set 7 | norman wells
# Processing Record 2 of Set 7 | chojnow
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | urumqi
# Processing Record 5 of Set 7 | pangnirtung
# Processing Record 6 of Set 7 | ivanteyevka
# Processing Record 7 of Set 7 | mandiana
# Processing Record 8 of Set 7 | dudinka
# Processing Record 9 of Set 7 | pokhara
# Processing Record 10 of Set 7 | hameenlinna
# Processing Record 11 of Set 7 | carnarvon
# Processing Record 12 of Set 7 | tyrma
# Processing Record 13 of Set 7 | longyearbyen
# Processing Record 14 of Set 7 | krasnoselkup
# Processing Record 15 of Set 7 | mosjoen
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | auki
# Processing Record 18 of Set 7 | humboldt
# Processing Record 19 of Set 7 | dong hoi
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | caravelas
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | laguna
# Processing Record 25 of Set 7 | dehui
# Processing Record 26 of Set 7 | stavelot
# Processing Record 27 of Set 7 | huambo
# Processing Record 28 of Set 7 | da nang
# Processing Record 29 of Set 7 | morant bay
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | haines junction
# Processing Record 32 of Set 7 | sinnamary
# Processing Record 33 of Set 7 | soderhamn
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | taunggyi
# Processing Record 37 of Set 7 | opuwo
# Processing Record 38 of Set 7 | santa cruz
# Processing Record 39 of Set 7 | cabinda
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | alofi
# Processing Record 42 of Set 7 | shingu
# Processing Record 43 of Set 7 | khanpur
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | tumut
# Processing Record 46 of Set 7 | kieta
# Processing Record 47 of Set 7 | turukhansk
# Processing Record 48 of Set 7 | charlestown
# Processing Record 49 of Set 7 | murupara
# Processing Record 50 of Set 7 | asau
# 350 sleeping...
# Processing Record 1 of Set 8 | eureka
# Processing Record 2 of Set 8 | ilulissat
# Processing Record 3 of Set 8 | xining
# Processing Record 4 of Set 8 | swan river
# Processing Record 5 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 8 | pisco
# Processing Record 7 of Set 8 | sao jose da coroa grande
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | aqtobe
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | sunyani
# Processing Record 12 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 8 | monrovia
# Processing Record 14 of Set 8 | angoche
# Processing Record 15 of Set 8 | iralaya
# Processing Record 16 of Set 8 | viile satu mare
# Processing Record 17 of Set 8 | buala
# Processing Record 18 of Set 8 | tommot
# Processing Record 19 of Set 8 | havre-saint-pierre
# Processing Record 20 of Set 8 | ribeira grande
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | actopan
# Processing Record 23 of Set 8 | nicoya
# Processing Record 24 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 8 | jacareacanga
# Processing Record 26 of Set 8 | barcelos
# Processing Record 27 of Set 8 | akdagmadeni
# Processing Record 28 of Set 8 | maridi
# Processing Record 29 of Set 8 | okakarara
# Processing Record 30 of Set 8 | victoria point
# Processing Record 31 of Set 8 | caraquet
# Processing Record 32 of Set 8 | ayan
# Processing Record 33 of Set 8 | severo-yeniseyskiy
# Processing Record 34 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 8 | corrente
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | longkou
# Processing Record 38 of Set 8 | santana do livramento
# Processing Record 39 of Set 8 | comodoro rivadavia
# Processing Record 40 of Set 8 | ranong
# Processing Record 41 of Set 8 | amasya
# Processing Record 42 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 8 | lander
# Processing Record 44 of Set 8 | los llanos de aridane
# Processing Record 45 of Set 8 | cururupu
# Processing Record 46 of Set 8 | kisangani
# Processing Record 47 of Set 8 | kautokeino
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | hachinohe
# Processing Record 50 of Set 8 | sharkan
# 400 sleeping...
# Processing Record 1 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 9 | vostok
# Processing Record 3 of Set 9 | malitbog
# Processing Record 4 of Set 9 | abu samrah
# Processing Record 5 of Set 9 | sokolo
# Processing Record 6 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 9 | iquique
# Processing Record 8 of Set 9 | bambanglipuro
# Processing Record 9 of Set 9 | newtownards
# Processing Record 10 of Set 9 | cedral
# Processing Record 11 of Set 9 | kabanjahe
# Processing Record 12 of Set 9 | potam
# Processing Record 13 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | piedras negras
# Processing Record 17 of Set 9 | antoniny
# Processing Record 18 of Set 9 | champerico
# Processing Record 19 of Set 9 | thakurdwara
# Processing Record 20 of Set 9 | sokoto
# Processing Record 21 of Set 9 | altay
# Processing Record 22 of Set 9 | palmer
# Processing Record 23 of Set 9 | nampa
# Processing Record 24 of Set 9 | kirishi
# Processing Record 25 of Set 9 | mujiayingzi
# Processing Record 26 of Set 9 | byron bay
# Processing Record 27 of Set 9 | isangel
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | severo-kurilsk
# Processing Record 30 of Set 9 | marathon
# Processing Record 31 of Set 9 | mirina
# City not found. Skipping...
# Processing Record 32 of Set 9 | cherdakly
# Processing Record 33 of Set 9 | dekar
# Processing Record 34 of Set 9 | paracuru
# Processing Record 35 of Set 9 | aksu
# Processing Record 36 of Set 9 | kristiinankaupunki
# Processing Record 37 of Set 9 | lagoa
# Processing Record 38 of Set 9 | kuruman
# Processing Record 39 of Set 9 | port-cartier
# Processing Record 40 of Set 9 | ulagan
# Processing Record 41 of Set 9 | praia
# Processing Record 42 of Set 9 | sipe sipe
# Processing Record 43 of Set 9 | brae
# Processing Record 44 of Set 9 | boddam
# Processing Record 45 of Set 9 | sovetskiy
# Processing Record 46 of Set 9 | baghdad
# Processing Record 47 of Set 9 | cuiluan
# Processing Record 48 of Set 9 | okhotsk
# Processing Record 49 of Set 9 | shalakusha
# Processing Record 50 of Set 9 | mutsamudu
# City not found. Skipping...
# 450 sleeping...
# Processing Record 1 of Set 10 | ati
# Processing Record 2 of Set 10 | ancud
# Processing Record 3 of Set 10 | chake chake
# Processing Record 4 of Set 10 | tartki
# City not found. Skipping...
# Processing Record 5 of Set 10 | mutare
# Processing Record 6 of Set 10 | lavumisa
# Processing Record 7 of Set 10 | burica
# City not found. Skipping...
# Processing Record 8 of Set 10 | sisimiut
# Processing Record 9 of Set 10 | san felipe
# Processing Record 10 of Set 10 | leningradskiy
# Processing Record 11 of Set 10 | verkhnyaya sinyachikha
# Processing Record 12 of Set 10 | aripuana
# Processing Record 13 of Set 10 | myingyan
# Processing Record 14 of Set 10 | broome
# Processing Record 15 of Set 10 | boali
# Processing Record 16 of Set 10 | sorland
# Processing Record 17 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 10 | namtsy
# Processing Record 19 of Set 10 | punta alta
# Processing Record 20 of Set 10 | lasa
# Processing Record 21 of Set 10 | arganil
# Processing Record 22 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 10 | chengde
# Processing Record 24 of Set 10 | lindi
# Processing Record 25 of Set 10 | dalvik
# Processing Record 26 of Set 10 | cabo san lucas
# Processing Record 27 of Set 10 | kahului
# Processing Record 28 of Set 10 | nurota
# Processing Record 29 of Set 10 | timra
# Processing Record 30 of Set 10 | nome
# Processing Record 31 of Set 10 | jojoima
# Processing Record 32 of Set 10 | uyuni
# Processing Record 33 of Set 10 | jacqueville
# Processing Record 34 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 10 | raipur
# Processing Record 36 of Set 10 | tambura
# Processing Record 37 of Set 10 | dinard
# Processing Record 38 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 10 | salinopolis
# Processing Record 40 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 10 | acapulco
# Processing Record 42 of Set 10 | sesheke
# Processing Record 43 of Set 10 | buin
# Processing Record 44 of Set 10 | yiyang
# Processing Record 45 of Set 10 | lososina
# Processing Record 46 of Set 10 | inuvik
# Processing Record 47 of Set 10 | mogadishu
# Processing Record 48 of Set 10 | norden
# Processing Record 49 of Set 10 | tarko-sale
# Processing Record 50 of Set 10 | kalmunai
# 500 sleeping...
# Processing Record 1 of Set 11 | winneba
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | murmashi
# Processing Record 4 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 11 | narsaq
# Processing Record 6 of Set 11 | woodburn
# Processing Record 7 of Set 11 | puerto leguizamo
# Processing Record 8 of Set 11 | lulea
# Processing Record 9 of Set 11 | chapais
# Processing Record 10 of Set 11 | sistranda
# Processing Record 11 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 11 | labuhan
# Processing Record 13 of Set 11 | nantucket
# Processing Record 14 of Set 11 | freeport
# Processing Record 15 of Set 11 | bethel
# Processing Record 16 of Set 11 | takaka
# Processing Record 17 of Set 11 | khuchni
# Processing Record 18 of Set 11 | nanortalik
# Processing Record 19 of Set 11 | wilmington
# Processing Record 20 of Set 11 | visby
# Processing Record 21 of Set 11 | surt
# Processing Record 22 of Set 11 | fort nelson
# Processing Record 23 of Set 11 | padang
# Processing Record 24 of Set 11 | port lincoln
# Processing Record 25 of Set 11 | college
# Processing Record 26 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 11 | mayskiy
# Processing Record 28 of Set 11 | bathsheba
# Processing Record 29 of Set 11 | kysyl-syr
# Processing Record 30 of Set 11 | zomin
# Processing Record 31 of Set 11 | anastacio
# Processing Record 32 of Set 11 | kununurra
# Processing Record 33 of Set 11 | tahoua
# Processing Record 34 of Set 11 | avallon
# Processing Record 35 of Set 11 | bo phloi
# Processing Record 36 of Set 11 | santa lucia cotzumalguapa
# Processing Record 37 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 38 of Set 11 | vung tau
# Processing Record 39 of Set 11 | rio gallegos
# Processing Record 40 of Set 11 | ostrovnoy
# Processing Record 41 of Set 11 | inhambane
# Processing Record 42 of Set 11 | chiang rai
# Processing Record 43 of Set 11 | mandalgovi
# Processing Record 44 of Set 11 | aykhal
# Processing Record 45 of Set 11 | ippy
# Processing Record 46 of Set 11 | manjakandriana
# Processing Record 47 of Set 11 | kungalv
# Processing Record 48 of Set 11 | buckeye
# Processing Record 49 of Set 11 | oklahoma city
# Processing Record 50 of Set 11 | crawfordsville
# 550 sleeping...
# Processing Record 1 of Set 12 | inirida
# Processing Record 2 of Set 12 | baruun-urt
# Processing Record 3 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 4 of Set 12 | sergeyevka
# Processing Record 5 of Set 12 | goderich
# Processing Record 6 of Set 12 | panzhihua
# Processing Record 7 of Set 12 | tancheng
# Processing Record 8 of Set 12 | shimoda
# Processing Record 9 of Set 12 | beloha
# Processing Record 10 of Set 12 | fort wellington
# Processing Record 11 of Set 12 | kentau
# Processing Record 12 of Set 12 | nankana sahib
# Processing Record 13 of Set 12 | puerto maldonado
# Processing Record 14 of Set 12 | reserva
# Processing Record 15 of Set 12 | tazmalt
# Processing Record 16 of Set 12 | icara
# Processing Record 17 of Set 12 | bella union
# Processing Record 18 of Set 12 | ekpoma
# Processing Record 19 of Set 12 | caucaia
# Processing Record 20 of Set 12 | klaksvik
# Processing Record 21 of Set 12 | san juan
# Processing Record 22 of Set 12 | port hawkesbury
# Processing Record 23 of Set 12 | ugoofaaru
# Processing Record 24 of Set 12 | aleksandrov gay
# Processing Record 25 of Set 12 | lengshuitan
# Processing Record 26 of Set 12 | saint-paul
# Processing Record 27 of Set 12 | tombouctou
# Processing Record 28 of Set 12 | asfi
# Processing Record 29 of Set 12 | mahibadhoo
# Processing Record 30 of Set 12 | sohag
# Processing Record 31 of Set 12 | lincoln
# Processing Record 32 of Set 12 | ucluelet
# Processing Record 33 of Set 12 | katherine
# Processing Record 34 of Set 12 | karpogory
# Processing Record 35 of Set 12 | le port
# Processing Record 36 of Set 12 | fundao
# Processing Record 37 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 12 | mayo
# Processing Record 39 of Set 12 | seoul
# Processing Record 40 of Set 12 | srednekolymsk
# Processing Record 41 of Set 12 | merauke
# Processing Record 42 of Set 12 | berlevag
# Processing Record 43 of Set 12 | guarapari
# Processing Record 44 of Set 12 | amahai
# Processing Record 45 of Set 12 | iracoubo
# Processing Record 46 of Set 12 | batagay-alyta
# Processing Record 47 of Set 12 | may pen
# Processing Record 48 of Set 12 | bakel
# Processing Record 49 of Set 12 | nizhniy chir
# Processing Record 50 of Set 12 | itupeva
# 600 sleeping...
# Processing Record 1 of Set 13 | misratah
# Processing Record 2 of Set 13 | moyale
# Processing Record 3 of Set 13 | nagorsk
# Processing Record 4 of Set 13 | manokwari
# Processing Record 5 of Set 13 | ripky
# Processing Record 6 of Set 13 | kibala
# Processing Record 7 of Set 13 | raudeberg
# Processing Record 8 of Set 13 | grand gaube
# Processing Record 9 of Set 13 | hervey bay
# Processing Record 10 of Set 13 | oranjemund
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 13 | tulum
# Processing Record 14 of Set 13 | turbat
# Processing Record 15 of Set 13 | sawtell
# Processing Record 16 of Set 13 | tahe
# Processing Record 17 of Set 13 | obigarm
# Processing Record 18 of Set 13 | dragor
# Processing Record 19 of Set 13 | puerto escondido
# Processing Record 20 of Set 13 | pleszew
# Processing Record 21 of Set 13 | zhigansk
# Processing Record 22 of Set 13 | kyabe
# Processing Record 23 of Set 13 | mnogovershinnyy
# Processing Record 24 of Set 13 | saint-pierre
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | budogoshch
# Processing Record 27 of Set 13 | camacha
# Processing Record 28 of Set 13 | uray
# Processing Record 29 of Set 13 | mount gambier
# Processing Record 30 of Set 13 | gayeri
# Processing Record 31 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 13 | antalaha
# Processing Record 33 of Set 13 | impfondo
# Processing Record 34 of Set 13 | shimanovsk
# Processing Record 35 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 13 | corrales
# Processing Record 37 of Set 13 | myaundzha
# Processing Record 38 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 13 | sanming
# Processing Record 40 of Set 13 | kapiri mposhi
# Processing Record 41 of Set 13 | verkhniy baskunchak
# Processing Record 42 of Set 13 | kurumkan
# Processing Record 43 of Set 13 | ferrol
# Processing Record 44 of Set 13 | sideropolis
# Processing Record 45 of Set 13 | gondar
# Processing Record 46 of Set 13 | otorohanga
# Processing Record 47 of Set 13 | price
# Processing Record 48 of Set 13 | methoni
# Processing Record 49 of Set 13 | irbil
# Processing Record 50 of Set 13 | tarnogskiy gorodok
# 650 sleeping...
# Processing Record 1 of Set 14 | bosaso
# Processing Record 2 of Set 14 | hit
# Processing Record 3 of Set 14 | saurimo
# Processing Record 4 of Set 14 | bubaque
# Processing Record 5 of Set 14 | belz
# Processing Record 6 of Set 14 | apiai
# Processing Record 7 of Set 14 | deputatskiy
# Processing Record 8 of Set 14 | mao
# Processing Record 9 of Set 14 | atar
# Processing Record 10 of Set 14 | dire dawa
# Processing Record 11 of Set 14 | bolcske
# Processing Record 12 of Set 14 | wageningen
# Processing Record 13 of Set 14 | chunian
# Processing Record 14 of Set 14 | katobu
# Processing Record 15 of Set 14 | tyret pervaya
# Processing Record 16 of Set 14 | healdsburg
# Processing Record 17 of Set 14 | peniche
# Processing Record 18 of Set 14 | alibag
# Processing Record 19 of Set 14 | hambantota
# Processing Record 20 of Set 14 | chipiona
# Processing Record 21 of Set 14 | goundam
# Processing Record 22 of Set 14 | agropoli
# Processing Record 23 of Set 14 | nelson bay
# Processing Record 24 of Set 14 | shelburne
# Processing Record 25 of Set 14 | mareeba
# Processing Record 26 of Set 14 | chongwe
# Processing Record 27 of Set 14 | ulaanbaatar
# Processing Record 28 of Set 14 | krasnyy yar
# Processing Record 29 of Set 14 | sire
# Processing Record 30 of Set 14 | tromso
# Processing Record 31 of Set 14 | vilya
# Processing Record 32 of Set 14 | tonj
# Processing Record 33 of Set 14 | pravec
# City not found. Skipping...
# Processing Record 34 of Set 14 | betafo
# Processing Record 35 of Set 14 | gualeguay
# Processing Record 36 of Set 14 | nabire
# Processing Record 37 of Set 14 | duren
# Processing Record 38 of Set 14 | ahipara
# Processing Record 39 of Set 14 | bilibino
# Processing Record 40 of Set 14 | pacific grove
# Processing Record 41 of Set 14 | victor harbor
# Processing Record 42 of Set 14 | camana
# Processing Record 43 of Set 14 | bowen
# Processing Record 44 of Set 14 | wilkie
# Processing Record 45 of Set 14 | lusambo
# Processing Record 46 of Set 14 | najran
# Processing Record 47 of Set 14 | tual
# Processing Record 48 of Set 14 | diffa
# Processing Record 49 of Set 14 | mangai
# Processing Record 50 of Set 14 | ulety
# 700 sleeping...
# Processing Record 1 of Set 15 | benguela
# Processing Record 2 of Set 15 | lalmanir hat
# City not found. Skipping...
# Processing Record 3 of Set 15 | dulce grande
# Processing Record 4 of Set 15 | manggar
# Processing Record 5 of Set 15 | tomatlan
# Processing Record 6 of Set 15 | balkhash
# Processing Record 7 of Set 15 | suntar
# Processing Record 8 of Set 15 | raga
# Processing Record 9 of Set 15 | menongue
# Processing Record 10 of Set 15 | solnechnyy
# Processing Record 11 of Set 15 | masumbwe
# Processing Record 12 of Set 15 | port hardy
# Processing Record 13 of Set 15 | mus
# Processing Record 14 of Set 15 | saint-leu
# Processing Record 15 of Set 15 | babaeski
# Processing Record 16 of Set 15 | redmond
# Processing Record 17 of Set 15 | kalevala
# Processing Record 18 of Set 15 | villamontes
# Processing Record 19 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 15 | qaqortoq
# Processing Record 21 of Set 15 | song phi nong
# Processing Record 22 of Set 15 | kemi
# Processing Record 23 of Set 15 | loikaw
# Processing Record 24 of Set 15 | gravdal
# Processing Record 25 of Set 15 | bratsk
# Processing Record 26 of Set 15 | oistins
# Processing Record 27 of Set 15 | rafai
# Processing Record 28 of Set 15 | rawson
# Processing Record 29 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 15 | manaus
# Processing Record 31 of Set 15 | catemaco
# Processing Record 32 of Set 15 | bandar-e lengeh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mehamn      NO  71.0357   27.8492     40.95        93          75
# 1          Borba      BR  -4.3878  -59.5939     84.92        57          71
# 2      Hithadhoo      MV  -0.6000   73.0833     81.82        70         100
# 3           Gizo      SB  -8.1030  156.8419     82.76        74         100
# 4  San Cristobal      VE   7.7669  -72.2250     82.58        61          18
# 5         Wajima      JP  37.4000  136.9000     74.55        71          94
# 6    Port Alfred      ZA -33.5906   26.8910     59.18        89          93
# 7          Erzin      TR  36.9559   36.2000     72.93        84          26
# 8      Bay-Khaak      RU  51.1667   94.5000     21.72        53           2
# 9       Ambilobe      MG -13.2000   49.0500     66.78        79          24
#
#    Wind Speed Current Description
# 0        4.61          light rain
# 1        1.03       broken clouds
# 2       15.17     overcast clouds
# 3        4.97     overcast clouds
# 4        4.21          few clouds
# 5       21.68     overcast clouds
# 6        3.00     overcast clouds
# 7        2.55    scattered clouds
# 8        3.11           clear sky
# 9        3.04          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mehamn      NO  71.0357   27.8492     40.95        93          75
# 1          Borba      BR  -4.3878  -59.5939     84.92        57          71
# 2      Hithadhoo      MV  -0.6000   73.0833     81.82        70         100
# 3           Gizo      SB  -8.1030  156.8419     82.76        74         100
# 4  San Cristobal      VE   7.7669  -72.2250     82.58        61          18
#
#    Wind Speed Current Description
# 0        4.61          light rain
# 1        1.03       broken clouds
# 2       15.17     overcast clouds
# 3        4.97     overcast clouds
# 4        4.21          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
